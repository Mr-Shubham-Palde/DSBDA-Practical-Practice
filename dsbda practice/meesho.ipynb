# %%
import requests
import bs4

# %%
req = requests.get('https://www.meesho.com/women-dresswestern-dress-for-womendress-for-womenwomen-dresswestern-dress-for-women-party-wear/p/6e0dpa')
req
# Out:
# <Response [200]>

# %%
req.content
# Out:
# b'<!DOCTYPE html><html lang="en"><head><title>women dress||western dress for women||dress for women||women dress||western dress for women party wear</title><meta name="description" content="Name: women dress||western dress for women||dress for women||women dress||western dress for women party wear\nFabric: Cotton Cambric\nSleeve Length: Three-Quarter Sleeves\nPattern: Solid\nNet Quantity (N): 1\nSizes:\nXXS, XS, S, M, L, XL, XXL\nFeaturing an intricate and beautifully crafted embroidered pattern, this women&#x27;s anarkali kurta is the epitome of elegance and style. And, its timeless design not only enhances your appearance but also boosts your confidence, helping you make a lasting impression in any setting.\nCountry of Origin: India"/><meta property="keywords" content="meesho,products"/><meta property="twitter:creator" content="Meesho"/><meta property="twitter:title" content="women dress||western dress for women||dress for women||women dress||western dress for women party wear"/><m
# ...

# %%
soup = bs4.BeautifulSoup(req.text)

# %%
reviews = soup.find_all('div',{'class':'sc-iBYQkv iVRyfE Comment__FlexRow-sc-1ju5q0e-1 cTbiMl Comment__FlexRow-sc-1ju5q0e-1 cTbiMl'})
for review in reviews:
    print(review.get_text()+'\n\n')
# Out:
# "Love this dress! It's perfect for a casual day out or a night on the town. The single piece design is flattering and comfortable, and the material is soft and breathable. The fit is true to size, and the color is exactly as shown. Highly recommend!" For more such review follow me on youtube or instagram @susmitatips.official Thank you ❤️
#
#
#
#
#
# I love the kurta reasonable price

# %%
rating = soup.find_all('span',{'class':'sc-eDvSVe laVOtN'})
for i in rating:
    print(i.get_text()+'\n\n')
# Out:
# 4.1
#
#
# 5.0
#
#
# 5.0

# %%
cust_name = soup.find_all('span',{'class':'sc-eDvSVe dugLmN'})
for i in cust_name:
    print(i.get_text()+'\n\n')
# Out:
# Susmita Jaiswal Gupta
#
#
# K Nagamani
